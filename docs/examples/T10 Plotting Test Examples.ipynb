# %% [markdown]
# # T10 Plotting Test Examples
#
# ### Rationale
#
# It is hard to write automated tests for live plotting behaviour. Our strategy is to run a live notebook with some mock instrument examples and see if everything behaves the way it should.

# %%
import numpy as np
import qcodes as qc
from qcodes.instrument.parameter import ArrayParameter
from qcodes.tests.instrument_mocks import DummyInstrument
from qcodes.utils.wrappers import do1d, do2d, do1dDiagonal, init

# %%
# Instruments to measure with

dac = DummyInstrument(name="dac", gates=['ch1', 'ch2'])  # The DAC voltage source
dmm = DummyInstrument(name="dmm", gates=['voltage'])  # The DMM voltage reader


# the default dummy instrument returns always a constant value, 
# in the following line we make it random 
# just for the looks 
import random
dmm.voltage.get =  lambda: random.randint(0, 100)

# We add an arrayparameter as well

class MyArray(ArrayParameter):
    """
    Arrayparameter which only purpose it to test that units, setpoints
    and so on are copied correctly to the individual arrays in the datarray.
    """

    def __init__(self, instrument=None, name='testparameter'):
        shape = (25,)
        label = 'this label'
        unit = 'this unit'
        sp_base = tuple(np.linspace(5, 9, 25))
        setpoints = (sp_base,)
        setpoint_names = ('this_setpoint',)
        setpoint_labels = ('this setpoint',)
        setpoint_units = ('this setpointunit',)
        self.get_multiplier = 1  # used to check AutoSIPrefix
        super().__init__(name,
                         shape,
                         instrument,
                         label=label,
                         unit=unit,
                         setpoints=setpoints,
                         setpoint_labels=setpoint_labels,
                         setpoint_names=setpoint_names,
                         setpoint_units=setpoint_units)

    def get(self):
        item = self.get_multiplier*np.random.randn(25)
        self._save_val(item)
        return item

dmm.add_parameter('myarray',
                  parameter_class=MyArray)

station = qc.Station(dac, dmm)

init(mainfolder='PlotTesting',
     sample_name='plottestsample',
     station=station,
     annotate_image=False)
# Out:
# Activating auto-logging. Current session state plus future input saved.
# Filename       : C:\Users\qcodes-william\Desktop\notebooks\PlotTesting\plottestsample\commands.log
# Mode           : append
# Output logging : True
# Raw input log  : False
# Timestamping   : True
# State          : active

# %%
station = qc.Station(dac, dmm)

# Finally, we instantiate the experiment. 
init(mainfolder='PlotTesting',
     sample_name='plottestsample',
     station=station,
     annotate_image=False)
# NB: In this test we don't annotate an image, but change False to True to do so

# %% [markdown]
# ## 1D Graphs

# %%
# Normal SI Units, normal interval
# Expected labels: 
#     Y: Gated Voltage (V), X: Gate ch1 (V)
plot, data = do1d(dac.ch1, 1, 10, 50, 0.01, dmm.voltage)
plot
# Out:
# Started at 2017-06-27 15:35:07
# DataSet:
#    location = 'C:\\Users\\qcodes-william\\Desktop\\notebooks\\PlotTesting\\plottestsample\\078'
#    <Type>   | <array_id>  | <array.name> | <array.shape>
#    Setpoint | dac_ch1_set | ch1          | (50,)
#    Measured | dmm_voltage | voltage      | (50,)
# Finished at 2017-06-27 15:35:09

# %%
# Normal SI Units, small setpoint range
# Expected labels: 
#     Y: Gated Voltage (V), X: Gate ch1 (μV)
plot, data = do1d(dac.ch1, 0, 10e-6, 50, 0.01, dmm.voltage)
plot
# Out:
# Started at 2017-06-27 15:35:11
# DataSet:
#    location = 'C:\\Users\\qcodes-william\\Desktop\\notebooks\\PlotTesting\\plottestsample\\079'
#    <Type>   | <array_id>  | <array.name> | <array.shape>
#    Setpoint | dac_ch1_set | ch1          | (50,)
#    Measured | dmm_voltage | voltage      | (50,)
# Finished at 2017-06-27 15:35:12

# %%
# Normal SI Units, small value range
# Expected labels: 
#     Y: Gated Voltage (uV), X: Gate ch1 (V)
dmm.voltage.get =  lambda: 1e-7*random.randint(0, 100)
plot, data = do1d(dac.ch1, 0, 10, 50, 0.01, dmm.voltage)
dmm.voltage.get =  lambda: random.randint(0, 100)
plot
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-6-e232e2f83569> in <module>()
#       3 #     Y: Gated Voltage (uV), X: Gate ch1 (V)
#       4 dmm.voltage.get =  lambda: 1e-7*random.randint(0, 100)
# ----> 5 plot, data = do1d(dac.ch1, 0, 10, 50, 0.01, dmm.voltage)
#       6 dmm.voltage.get =  lambda: random.randint(0, 100)
#       7 plot
#
# \\tsclient\sourcecodes\qdev-dk\qcodes\utils\wrappers.py in do1d(inst_set, start, stop, num_points, delay, do_plots, *inst_meas)
#     428
#     429     plot, data = _do_measurement(loop, set_params, meas_params,
# --> 430                                  do_plots=do_plots)
#     431
#     432     return plot, data
#
# \\tsclient\sourcecodes\qdev-dk\qcodes\utils\wrappers.py in _do_measurement(loop, set_params, meas_params, do_plots)
#     362
#     363     if do_plots:
# --> 364         plot, _ = _plot_setup(data, plottables, startranges=startranges)
#     365     else:
#     366         plot = None
#
# \\tsclient\sourcecodes\qdev-dk\qcodes\utils\wrappers.py in _plot_setup(data, inst_meas, useQT, startranges)
#     125             num_subplots += 1
#     126     if useQT:
# --> 127         plot = QtPlot(fig_x_position=CURRENT_EXPERIMENT['plot_x_position'])
#     128     else:
#     129         plot = MatPlot(subplots=(1, num_subplots))
#
# \\tsclient\sourcecodes\qdev-dk\qcodes\plots\pyqtgraph.py in __init__(self, figsize, interval, window_title, theme, show_window, remote, fig_x_position, *args, **kwargs)
#      62             # overrule the remote pyqtgraph class
#      63             self.rpg = pg
# ---> 64         self.win = self.rpg.GraphicsWindow(title=window_title)
#      65         self.win.setBackground(theme[1])
#      66         self.win.resize(*figsize)
#
# c:\users\qcodes-william\anaconda3\envs\test-setup\lib\site-packages\pyqtgraph\multiprocess\remoteproxy.py in __getattr__(self, attr, **kwds)
#     895         else:
#     896             #opts = self._getProxyOptions()
# --> 897             return self._handler.getObjAttr(self, attr, **opts)
#     898
#     899     def _deferredAttr(self, attr):
#
# c:\users\qcodes-william\anaconda3\envs\test-setup\lib\site-packages\pyqtgraph\multiprocess\remoteproxy.py in getObjAttr(self, obj, attr, **kwds)
#     530
#     531     def getObjAttr(self, obj, attr, **kwds):
# --> 532         return self.send(request='getObjAttr', opts=dict(obj=obj, attr=attr), **kwds)
#     533
#     534     def getObjValue(self, obj, **kwds):
#
# c:\users\qcodes-william\anaconda3\envs\test-setup\lib\site-packages\pyqtgraph\multiprocess\remoteproxy.py in send(self, request, opts, reqId, callSync, timeout, returnType, byteData, **kwds)
#     450             request = (request, reqId, nByteMsgs, optStr)
#     451             self.debugMsg('send request: cmd=%s nByteMsgs=%d id=%s opts=%s', request[0], nByteMsgs, reqId, opts)
# --> 452             self.conn.send(request)
#     453
#     454             ## follow up by sending byte messages
#
# c:\users\qcodes-william\anaconda3\envs\test-setup\lib\multiprocessing\connection.py in send(self, obj)
#     204         self._check_closed()
#     205         self._check_writable()
# --> 206         self._send_bytes(ForkingPickler.dumps(obj))
#     207
#     208     def recv_bytes(self, maxlength=None):
#
# c:\users\qcodes-william\anaconda3\envs\test-setup\lib\multiprocessing\connection.py in _send_bytes(self, buf)
#     402             # Also note we want to avoid sending a 0-length buffer separately,
#     403             # to avoid "broken pipe" errors if the other end closed the pipe.
# --> 404             self._send(header + buf)
#     405
#     406     def _recv_bytes(self, maxsize=None):
#
# c:\users\qcodes-william\anaconda3\envs\test-setup\lib\multiprocessing\connection.py in _send(self, buf, write)
#     366         remaining = len(buf)
#     367         while True:
# --> 368             n = write(self._handle, buf)
#     369             remaining -= n
#     370             if remaining == 0:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %%
# Exceptional Units, small setpoint range
# Expected labels: 
#     Y: Gated Voltage (V), X: Gate ch1 (V)
dmm.voltage.get =  lambda: 1e-7*random.randint(0, 100)
dmm.voltage.unit = 'XX'
plot, data = do1d(dac.ch1, 0, 10, 50, 0.01, dmm.voltage)
dmm.voltage.get =  lambda: random.randint(0, 100)
dmm.voltage.unit = 'V'
plot
# Out:
# Started at 2017-06-27 14:20:50
# DataSet:
#    location = 'C:\\Users\\qcodes-william\\Desktop\\notebooks\\PlotTesting\\plottestsample\\067'
#    <Type>   | <array_id>  | <array.name> | <array.shape>
#    Setpoint | dac_ch1_set | ch1          | (50,)
#    Measured | dmm_voltage | voltage      | (50,)
# Finished at 2017-06-27 14:20:51

# %%
# Exceptional Units, small set range
# Expected labels: 
#     Y: Gated Voltage (XX), X: Gate ch1 (V)
dac.ch1.unit = 'YY'
plot, data = do1d(dac.ch1, 0, 10e-7, 50, 0.01, dmm.voltage)
dac.ch1.unit = 'V'
plot
# Out:
# Started at 2017-06-27 14:20:53
# DataSet:
#    location = 'C:\\Users\\qcodes-william\\Desktop\\notebooks\\PlotTesting\\plottestsample\\068'
#    <Type>   | <array_id>  | <array.name> | <array.shape>
#    Setpoint | dac_ch1_set | ch1          | (50,)
#    Measured | dmm_voltage | voltage      | (50,)
# Finished at 2017-06-27 14:20:55

# %%
# Normal SI Units, normal interval, sloooow acquisition. Zoom out/pan and check autozoom
# Expected labels: 
#     Y: Gated Voltage (V), X: Gate ch1 (V)
plot, data = do1d(dac.ch1, 1, 10, 10, 1, dmm.voltage)
plot
# Out:
# Started at 2017-06-27 14:20:56
# DataSet:
#    location = 'C:\\Users\\qcodes-william\\Desktop\\notebooks\\PlotTesting\\plottestsample\\069'
#    <Type>   | <array_id>  | <array.name> | <array.shape>
#    Setpoint | dac_ch1_set | ch1          | (10,)
#    Measured | dmm_voltage | voltage      | (10,)
# Finished at 2017-06-27 14:21:06

# %% [markdown]
# ## 2D Graphs

# %% [markdown]
# ### `do1d` with array parameter

# %%
# Exceptional Units, small set range
# Expected labels: 
#     X: This setpoint (this setpointunit), Y: Gate ch1 (μV)

plot, data = do1d(dac.ch1, 0, 10e-7, 50, 0.01, dmm.myarray)

plot
# Out:
# Started at 2017-06-27 14:21:08
# DataSet:
#    location = 'C:\\Users\\qcodes-william\\Desktop\\notebooks\\PlotTesting\\plottestsample\\070'
#    <Type>   | <array_id>  | <array.name> | <array.shape>
#    Setpoint | dac_ch1_set | ch1          | (50,)
#    Measured | dmm_myarray | myarray      | (50, 25)
# Finished at 2017-06-27 14:21:12

# %%
# Exceptional Units, small set range, large value range
# Expected labels: 
#     X: This setpoint (this setpointunit), Y: Gate ch1 (μV), Z: this label (GHz)

dmm.myarray.get_multiplier = 1e9
dmm.myarray.unit = 'Hz'

plot, data = do1d(dac.ch1, 0, 10e-7, 50, 0.01, dmm.myarray)

def get(self):
    item = np.random.randn(25)
    self._save_val(item)
    return item

dmm.myarray.get_multiplier = 1
dmm.myarray.unit = 'this unit'

plot
# Out:
# Started at 2017-06-27 14:21:14
# DataSet:
#    location = 'C:\\Users\\qcodes-william\\Desktop\\notebooks\\PlotTesting\\plottestsample\\071'
#    <Type>   | <array_id>  | <array.name> | <array.shape>
#    Setpoint | dac_ch1_set | ch1          | (50,)
#    Measured | dmm_myarray | myarray      | (50, 25)
# Finished at 2017-06-27 14:21:19

# %%
# Long delay, watch out for blank plot ranges and check autozoom
# Expected range:
#     X: 5-9 (this setpointunit), Y: 0-1 μV
# 
plot, data = do1d(dac.ch1, 0, 10e-7, 3, 5, dmm.myarray)

plot
# Out:
# Started at 2017-06-27 14:21:21
# DataSet:
#    location = 'C:\\Users\\qcodes-william\\Desktop\\notebooks\\PlotTesting\\plottestsample\\072'
#    <Type>   | <array_id>  | <array.name> | <array.shape>
#    Setpoint | dac_ch1_set | ch1          | (3,)
#    Measured | dmm_myarray | myarray      | (3, 25)
# Finished at 2017-06-27 14:21:36

# %% [markdown]
# ## `do2d`

# %%
# Expected labels:
#     X: Gate ch2 (V), Y: Gate ch1 (μV), Z: Gate voltage (V)
# Check pan/autozoom
plot, data = do2d(dac.ch1, 0, 10e-7, 100, 0.005,
                  dac.ch2, 0, 10, 55, 0.005, dmm.voltage)
plot
# Out:
# Started at 2017-06-27 14:21:38
# DataSet:
#    location = 'C:\\Users\\qcodes-william\\Desktop\\notebooks\\PlotTesting\\plottestsample\\073'
#    <Type>   | <array_id>  | <array.name> | <array.shape>
#    Setpoint | dac_ch1_set | ch1          | (100,)
#    Setpoint | dac_ch2_set | ch2          | (100, 55)
#    Measured | dmm_voltage | voltage      | (100, 55)
# Finished at 2017-06-27 14:22:16

# %%
# Expected labels:
#     X: Gate ch2 (V), Y: Gate ch1 (μV), Z: Gate voltage (MV)
# Check pan/autozoom
dmm.voltage.get = lambda: 1e6*random.randint(0, 100)
plot, data = do2d(dac.ch1, 0, 10e-7, 100, 0.1,
                  dac.ch2, 0, 10, 55, 0.01,
                  dmm.voltage)
dmm.voltage.get = lambda: random.randint(0, 100)
plot
# Out:
# Started at 2017-06-27 14:22:17
# DataSet:
#    location = 'C:\\Users\\qcodes-william\\Desktop\\notebooks\\PlotTesting\\plottestsample\\074'
#    <Type>   | <array_id>  | <array.name> | <array.shape>
#    Setpoint | dac_ch1_set | ch1          | (100,)
#    Setpoint | dac_ch2_set | ch2          | (100, 55)
#    Measured | dmm_voltage | voltage      | (100, 55)
# Finished at 2017-06-27 14:23:31

# %% [markdown]
# ## `do1dDiagonal`

# %%
plot, data = do1dDiagonal(dac.ch1, dac.ch2, 0, 5, 50, 0.01,
                          0, 0.2, 
                          dmm.voltage)
plot
# Out:
# Started at 2017-06-27 14:31:06
# DataSet:
#    location = 'C:\\Users\\qcodes-william\\Desktop\\notebooks\\PlotTesting\\plottestsample\\077'
#    <Type>   | <array_id>  | <array.name> | <array.shape>
#    Setpoint | dac_ch1_set | ch1          | (50,)
#    Measured | dmm_voltage | voltage      | (50,)
#    Measured | dac_ch2     | ch2          | (50,)
# Finished at 2017-06-27 14:31:07
